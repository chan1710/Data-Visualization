# %% [markdown]
# # Môn Trực quan hoá dữ liệu
# * Sinh viên: Huỳnh Thị Bảo Trân
# * MSSV: 19110482

# %% [markdown]
# # Bài làm

# %% [markdown]
# 0. Các thư viện được sử dụng trong bài

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# 1.
# * Đọc file csv.
# * In ra 5 rows đầu tiên.
# * In ra info và describe của file đã cho.
# * Cho biết số lượng records và features.
# * Cho biết các trường missing value.

# %%
dataset = pd.read_csv('dataset_truc_quan_hoa_du_lieu.csv')
dataset
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
dataset.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %%
dataset.describe()
# Out:
#                 Age
# count  1.259000e+03
# mean   7.942815e+07
# std    2.818299e+09
# min   -1.726000e+03
# 25%    2.700000e+01
# 50%    3.100000e+01
# 75%    3.600000e+01
# max    1.000000e+11

# %%
dataset.count()
# Out:
# Timestamp                    1259
# Age                          1259
# Gender                       1259
# Country                      1259
# state                         744
# self_employed                1241
# family_history               1259
# treatment                    1259
# work_interfere                995
# no_employees                 1259
# remote_work                  1259
# tech_company                 1259
# benefits                     1259
# care_options                 1259
# wellness_program             1259
# seek_help                    1259
# anonymity                    1259
# leave                        1259
# mental_health_consequence    1259
# phys_health_consequence      1259
# coworkers                    1259
# supervisor                   1259
# mental_health_interview      1259
# phys_health_interview        1259
# mental_vs_physical           1259
# obs_consequence              1259
# comments                      164
# dtype: int64

# %%
dataset.loc[:, dataset.isnull().any()]
# Out:
#      state self_employed work_interfere comments
# 0       IL           NaN          Often      NaN
# 1       IN           NaN         Rarely      NaN
# 2      NaN           NaN         Rarely      NaN
# 3      NaN           NaN          Often      NaN
# 4       TX           NaN          Never      NaN
# ...    ...           ...            ...      ...
# 1254   NaN            No            NaN      NaN
# 1255    IL            No          Often      NaN
# 1256    CA            No      Sometimes      NaN
# 1257    NC            No            NaN      NaN
# 1258    IL            No      Sometimes      NaN
#
# [1259 rows x 4 columns]

# %% [markdown]
# 2.
# * Cleaning lại cột Age, giá trị của cột Age nằm trong giới hạn từ 0 đến 100 ([0:100]), nếu không thuộc giới hạn trên thì thay bằng Nan(np.nan).
# * Vẽ biểu đồ phân bố độ tuổi (Age Distrubtion) từ cột Age đã drop nan.

# %%
data_age = dataset[(dataset.Age > 0) & (dataset.Age < 100)]
data_age
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
sns.displot(data = data_age, x = 'Age', kde = True, aspect = 2, palette = 'RdYlGn')

# %% [markdown]
# 3.
# * Vẽ biểu đồ biểu diễn 10 quốc gia có số lượng records nhiều nhất ("Top 10 Country")

# %%
dataset.Country.value_counts()
dataset
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
top_countries = ['United States','United Kingdom','Canada','Germany','Netherlands','Ireland','Australia','France','India','New Zealand']

data_country = dataset[(dataset.Country.isin(top_countries))]
data_country
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
sns.catplot('Country', data = data_country, kind = 'count', aspect = 2, palette = 'RdYlGn')
# Out:
# C:\Users\Justmechan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# 4.
# * Vẽ biểu đồ phân bố ở cột treatment (Treatment Distribution).

# %%
data_treatment = pd.DataFrame(dataset.treatment)
data_treatment.value_counts()
# Out:
# treatment
# Yes          637
# No           622
# dtype: int64

# %%
sns.barplot(x = 'treatment', y = data_treatment.index, data = data_treatment, palette = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='treatment'>

# %% [markdown]
# 5.
# * Thống kê số lượng yes/no ở cột family_history theo các nhóm tuổi : <18, 18-24, 25-34, 35-44, 45+ ở cột Age. Chú ý: Cột Age không lấy giá trị Nan.
# * Từ đó vẽ biểu đồ biểu diễn số lượng yes/no của family_history theo từng nhóm tuổi.

# %%
data_age = dataset.loc[(dataset['Age'] >= 0) & (dataset['Age'] <= 100)]
data_age
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
data1 = data_age.nsmallest(3, 'Age')
data_1 = data1['family_history'].value_counts()
data_1 = pd.DataFrame(data_1)
sns.barplot(x = 'family_history', y = data_1.index, data = data_1, palette = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='family_history'>

# %%
data2 = data_age.loc[(data_age['Age'] >= 18) & (data_age['Age'] <= 24)]
data_2 = data2['family_history'].value_counts()
data_2 = pd.DataFrame(data_2)
sns.barplot(x = 'family_history', y = data_2.index, data = data_2, palette = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='family_history'>

# %%
data3 = data_age.loc[(data_age['Age'] >= 25) & (data_age['Age'] <= 34)]
data_3 = data3['family_history'].value_counts()
data_3 = pd.DataFrame(data_3)
sns.barplot(x = 'family_history', y = data_3.index, data = data_3, palette = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='family_history'>

# %%
data4 = data_age.loc[(data_age['Age'] >= 35) & (data_age['Age'] <= 44)]
data_4 = data4['family_history'].value_counts()
data_4 = pd.DataFrame(data_4)
sns.barplot(x = 'family_history', y = data_4.index, data = data_4, palette = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='family_history'>

# %%
data5 = data_age.loc[(data_age['Age'] > 45)]
data_5 = data3['family_history'].value_counts()
data_5 = pd.DataFrame(data_5)
sns.barplot(x = 'family_history', y = data_5.index, data = data_5, palette = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='family_history'>

# %% [markdown]
# 6.
# * Tương tự cậu 5, nhưng thay cột family_history thành cột treatment.

# %%
data1 = data_age.nsmallest(3, 'Age')
data_1 = data1['treatment'].value_counts()
data_1 = pd.DataFrame(data_1)
sns.barplot(x = 'treatment', y = data_1.index, data = data_1, palette = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='treatment'>

# %%
data2 = data_age.loc[(data_age['Age'] >= 18) & (data_age['Age'] <= 24)]
data_2 = data2['treatment'].value_counts()
data_2 = pd.DataFrame(data_2)
sns.barplot(x = 'treatment', y = data_2.index, data = data_2, palette = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='treatment'>

# %%
data3 = data_age.loc[(data_age['Age'] >= 25) & (data_age['Age'] <= 34)]
data_3 = data3['treatment'].value_counts()
data_3 = pd.DataFrame(data_3)
sns.barplot(x = 'treatment', y = data_3.index, data = data_3, palette = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='treatment'>

# %%
data4 = data_age.loc[(data_age['Age'] >= 35) & (data_age['Age'] <= 44)]
data_4 = data4['treatment'].value_counts()
data_4 = pd.DataFrame(data_4)
sns.barplot(x = 'treatment', y = data_4.index, data = data_4, palette = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='treatment'>

# %%
data5 = data_age.loc[(data_age['Age'] > 45)]
data_5 = data3['treatment'].value_counts()
data_5 = pd.DataFrame(data_5)
sns.barplot(x = 'treatment', y = data_5.index, data = data_5, palette = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='treatment'>

# %% [markdown]
# 7.
# * Vẽ biểu đồ phân bố ở cột work_interfere (work_nterfere Distribution)
# * Xác định các unique và số lượng tương ứng của cột no_employee và vẽ biểu đồ biểu diễn các unique này theo tỉ lệ phần trăm.
# Chú ý: Nhớ thực hiện bỏ missing values.

# %%
data_workinterfere = pd.DataFrame(dataset.work_interfere)
data_workinterfere.value_counts()
# Out:
# work_interfere
# Sometimes         465
# Never             213
# Rarely            173
# Often             144
# dtype: int64

# %%
sns.barplot(x = 'work_interfere', y = data_workinterfere.index, data = data_workinterfere, palette = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='work_interfere'>

# %% [markdown]
# 8.
# * Vẽ biểu đồ biễn diễn số lượng yes/no của cột tech_company theo từng unique của cột no_employee.
# * Tương tự ý trên nhưng thay cột tech_company thành remote_work.

# %% [markdown]
# 9.
# * Hiện tại cột Gender có rất nhiều giá trị khác nhau ví dụ:
# Nam : thì có giá trị Male, M, male ... Nữ: thì có giá trị F, female, Female.
# * Chuẩn hóa cột Gender về 3 giá trị: Male, Female, Another (Nếu không xác định được).
# * Vẽ biểu đồ biểu diễn số lượng Male, Female, Another trong cột Gender sau chuẩn hóa.

# %% [markdown]
# 10.
# Dataset là khảo sát về sức khỏe tinh thần (mental health) và thông tin các cột như sau:
# * Age : Respondent age
# * Gender: Respondent gender
# * treatment: Have you sought treatment for a mental health condition?
# * family_history : Do you have a family history of mental illness?
# * work_interfere: If you have a mental health condition, do you feel that it interferes with your work?
# * no_employee: How many employees does your company or organization have?
# * tech_company: Is your employer primarily a tech company/organization?
# * remote_work: Do you work remotely (outside of an office) at least 50% of the time?
#
# Và từ các biểu đồ bạn đã vẽ, bạn có nhận xét gì sức khỏe tinh thần (mental health) của dataset đã cho?

# %% [markdown]
# Người khảo sát có cảm thấy ảnh hưởng công việc khi sức khoẻ tinh thần không tốt.
# Độ tuổi trung bình của người khảo sát khoảng 30 tuổi.
